# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

# %%
import echidna as data

# %% [markdown]
# # Get to know the data

# %%
# the features: data.X 

# determine the number of features

# determine the number of examples

# %%
# the labels: data.Y

# determine the number of classes

# %%
# plot the data

plt.plot(data.X[data.Y[:,0]==0, 0], data.X[data.Y[:,0]==0, 1], '.')
plt.plot(data.X[data.Y[:,0]==1, 0], data.X[data.Y[:,0]==1, 1], '+')

# why is it called echidna? https://en.wikipedia.org/wiki/Echidna

# %%
# now train a neural net (one hidden layer) on these data
